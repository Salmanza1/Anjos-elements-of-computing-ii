# %% [markdown]
# ### __Quick Introduction to the Iris Dataset:__
#
# The Iris dataset, often called the "Hello World" of machine learning, is one of the most famous and enduring datasets in data science. Compiled in the 1930s, it remains a standard benchmark for classification, clustering, and visualization tasks.
#
# __FUN FACT:__ The Iris dataset is older than modern computing. The data was collected by American botanist Edgar Anderson in 1935.
#
# ____________________________________________________________________________________________________________
#
# Dataset Structure:
# * The dataset consists of 150 samples, with 50 samples from three species.
#
# Four Features (Measurements in cm):
# * Sepal Length: The length of the outer green leaf-like structures.
# * Sepal Width: The width of the sepals.
# * Petal Length: The length of the inner colored petals.
# * Petal Width: The width of the petals.
#
# Three Target Species:
# * Iris setosa (often encoded as 0).
# * Iris versicolor (often encoded as 1).
# * Iris virginica (often encoded as 2).

# %%
# Import Libraries 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Import Dataset
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### __Dataset Overview__
#
# Now, that we have prepared our environment and loaded our dataset, let's take a closer look at the variables and observations.
#
# To do this, we will use a function called [.info()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html).
#
#
# __Q: What does the documentation say is the output of the function .info()?__

# %%
# Exploring .info()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Section 1: Distribution
#
# __Question 1:__ What does the distribution of sepal length look like across all species in the Iris dataset?
#
# To answer this question, let's first make sure we understand the question being asked.
#
# ____________________________________________________________________________________________________________
#
# #### __What is distribution in terms of data visualization?__
# * It is the graphical representation of how data points are spread out, grouped, or clustered, therefore displaying where the majority of data points lie.
#
# #### __What is sepal length?__
# * Sepal length is the length of the outer green leaf-like structures.
#
# #### __What do we know about the variable sepal length in this dataset?__
# Let's use the ([.sort_values()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html)) function. This will sort all specified values in ascending order.
#
# __Q: What does the documentation say is the output of the function .sort_values()?__

# %%
# Exploring .sort_values()
#Answer: Sort by the values along either axis
df["sepal_length"].sort_values()
# Out:
# 13     4.3
# 42     4.4
# 38     4.4
# 8      4.4
# 41     4.5
#       ...
# 122    7.7
# 118    7.7
# 117    7.7
# 135    7.7
# 131    7.9
# Name: sepal_length, Length: 150, dtype: float64

# %% [markdown]
# From this output, we now know that the variable `sepal_length` has a numerical (dtype: float64) value range from 4.3cm being the lowest to 7.9cm being the highest.
#
# Now, that we have a better understanding of the variable we are examing, let's answer the original question.
#
# __________________________________________________________________________________________________
#
# ### __Question 1:__ What does the distribution of sepal length look like across all species in the Iris dataset?
#
# * Open our helpful website [data-to-viz](https://www.data-to-viz.com/).
# * Once in the website, scroll down to the section __A World of Possibilities__.
# * Look at __Distribution__. There are a five options available.
# * Click on __Violin__.
#
# Take a second and read the __ABOUT__ section.
#
# * Now, scroll down and click __Python__ and scroll down to the section labeled "Quick Start".
# * Copy/paste the line of code under `# plot` into the code cell below.

# %%
# Plot using a violin
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')

# plot
sns.violinplot(x=df["species"], y=df["sepal_length"])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# Now, let's add some more parameters to make this visualization more robust.

# %%
# Plot with style and hue parameters
sns.set_theme(style="darkgrid") # style = background 
sns.violinplot(x=df["species"], y=df["sepal_length"],hue=df["species"]) # hue = violin color

# Add a title
plt.title("Violin Plot of Sepal Length by Species")
# Out:
# Text(0.5, 1.0, 'Violin Plot of Sepal Length by Species')

# %% [markdown]
# ### Understanding Violinplots
#
# * The white line represents the median.
#
# * The thick gray bar in the center represents the interquartile range (spread of the middle half of the data).
#
# * The gray lines on both sides of the interquartile range represent the rest of the distribution.
#
# * The outlining gray sides show the distribution shape of the data. Wider sections of the violinplot show where higher representation of the data occurs and thinner sections vice versa.
#
# __________________________________________________________________________________________________
#
# Now, revisit the [data-to-viz](https://www.data-to-viz.com/) website.
# * Locate the documentation on "Histograms".
# * Copy/paste the python code provided in the cell below.

# %%
# Plot the histogram thanks to the .displot() function

# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')

# Plot the histogram thanks to the displot function
sns.displot( data=df["sepal_length"], kde=True )

# %% [markdown]
# Now, let's visualize using the .histplot() function.

# %%
# Plot the histogram thanks to the histplot function with the hue parameter and the element parameter
sns.histplot( data=df, x="sepal_length", hue="species", element="step", stat="density", common_norm=False )

#the mix of colorsare the intersection of the 3 species, which means that they have similar sepal lengths.
#there is overlapping noww between the 3 species, which means that they have similar sepal lengths. from the histogram, we can see that the sepal length of the setosa species is around 5.0, while the versicolor and virginica species have a sepal length around 6.0 and 7.0 respectively.
#WHEN we add the elemnt parameter, we can see that the distribution of the sepal length for each species is more clear, and we can see that the setosa species has a sepal length around 5.0, while the versicolor and virginica species have a sepal length around 6.0 and 7.0 respectively.
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# #### __Class Discussion:__
#
# __Q:__ What was the difference between the outputs from .displot() and .histplot()?
# __________________________________________________________________________________________________
#
# Now, return to the [data-to-viz](https://www.data-to-viz.com/) website.
# * Click __Chart Types__ from the menu bar.
#
# __Group A:__
# * In the first row of icons, click on 5th icon. This is a ridgeline chart, also known as a joyplot.
# * Click on "About this chart".
# * Take a moment and read about __Ridgeline plots__.
#
# __Group B:__
# * In the first row of icons, click on 6th icon. This is a beeswarm plot, also known as a swarmplot.
# * Scroll down the page to the section titiled "swarmplot() function parameters".
# * Take a moment and read about __Swarm plots__ in seaborn.

# %%
# Group A: Create the ridgeline plot

sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
iris = sns.load_dataset("iris")

# Initialize the FacetGrid object
g = sns.FacetGrid(iris, row="species", hue="species", aspect=15, height=.5)

# Draw the densities
g.map(sns.kdeplot, "sepal_length", bw_adjust=.5, clip_on=False, fill=True, alpha=1, linewidth=1.5)
g.map(sns.kdeplot, "sepal_length", clip_on=False, color="w", lw=2, bw_adjust=.5)

# Add labeling function
def label(x, color, label):
    ax = plt.gca()
    # x=0 is left, y=.2 is slightly above baseline
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)

g.map(label, "sepal_length")

# Final styling to make them overlap
g.figure.subplots_adjust(hspace=-.25)
g.set_titles("")
g.figsize=(10, 6)
g.set(yticks=[], ylabel="")
g.despine(bottom=True, left=True)
plt.show()

#when is the ridgeline plot useful?
#The ridgeline plot is useful when we want to compare the distribution of a variable across different categories. It allows us to see the shape of the distribution for each category and how they overlap
#the ridgeline is showing us the distribution of the sepal length for each species, and we can see that the setosa species has a sepal length around 5.0, while the versicolor and virginica species have a sepal length around 6.0 and 7.0 respectively. We can also see that the distribution of the sepal length for the setosa species is more narrow than the other two species, which means that the sepal length of the setosa species is more consistent than the other two species.
#i also see that the distribution of the sepal length for the versicolor and virginica species is more wide than the setosa species, which means that the sepal length of the versicolor and virginica species is more variable than the setosa species.
# Out:
# /opt/miniconda3/envs/eoc/lib/python3.13/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /opt/miniconda3/envs/eoc/lib/python3.13/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /opt/miniconda3/envs/eoc/lib/python3.13/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /opt/miniconda3/envs/eoc/lib/python3.13/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
# ...

# %%
# Group B: Create the beeswarm plot

plt.figure(figsize=(8, 6))
sns.swarmplot(x="species", y="petal_length", hue="species", data=iris, palette="viridis", size=5)

# Add titles and labels
plt.title("Beeswarm Plot of Iris Petal Lengths by Species")
plt.xlabel("Species")
plt.ylabel("Petal Length (cm)")

# Show the plot
plt.show()

#showing us the distribution of the petal length for each species, and we can see that the setosa species has a petal length around 1.0, while the versicolor and virginica species have a petal length around 4.0 and 5.0 respectively. We can also see that the distribution of the petal length for the setosa species is more narrow than the other two species, which means that the petal length of the setosa species is more consistent than the other two species.

# %% [markdown]
# #### __Class Discussion:__
#
# __Q:__ What did you observe and or what became clearer from your groups' visualization?
#
# __Q:__ Compare ridgeline and beeswarm. What are the benefits and drawbacks of of using these two types of visualizations?

# %%
#what did you observe in the ridgeline plot?
#

# %% [markdown]
# ### __Answer to Question 1:__
# A comparison of sepal length across the three Iris species reveals a clear hierarchy in size, though with significant overlap between the larger two species.
# * __Iris setosa:__ Has the smallest sepal length.
# * __Iris versicolor:__ Occupies the middle ground.
# * __Iris virginica:__ Generally has the longest sepals and exhibits the widest spread of values.
#
# Did you observe any additional insights?
# __________________________________________________________________________________________________

# %% [markdown]
# # Section 2: Correlation

# %% [markdown]
# __Question 2:__ What is the correlation of sepal length to sepal width look like across all species in the Iris dataset?
#
# Again, let's first make sure we understand the question being asked.
#
# __________________________________________________________________________________________________
#
# #### __What is correlation in terms of data visualization?__
# * Correlation tells you how two variables move in relation to one another.
# * Correlations can be positive or negative.
#
# #### __What are sepal length and sepal width?__
# * Sepal length is the length of the outer green leaf-like structures.
# * Sepal width is the width of the sepals.
#
# #### __What do we know about the variable sepal width in this dataset?__
# Let's use the ([.sort_values()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html)) function again. Remember, this will sort all specified values in ascending order.

# %%
df["sepal_width"].sort_values()
# Out:
# 60     2.0
# 62     2.2
# 119    2.2
# 68     2.2
# 41     2.3
#       ...
# 16     3.9
# 14     4.0
# 32     4.1
# 33     4.2
# 15     4.4
# Name: sepal_width, Length: 150, dtype: float64

# %% [markdown]
# We now know that the variable `sepal_width` has a numerical (dtype: float64) value range from 2.0cm being the lowest to 4.4cm being the highest.
#
# Now, that we have a better understanding of the variable we are examing, let's answer the original question.
#
# __________________________________________________________________________________________________
#
# ### __Question 2:__ What is the correlation of sepal length to sepal width look like across all species in the Iris dataset?
#
# * Open our helpful website [data-to-viz](https://www.data-to-viz.com/) again.
# * Once in the website, scroll down to the section __A World of Possibilities__.
# * Look at __Correlation__. There are a six options available.
# * Click on __Scatterplot__. Then click __Python__.
# * Now, copy/paste the line of code under `# use the function scatterplot() to make a scatterplot` into the code cell below.

# %%
# use the .scatterplot() function to make a scatterplot
 # library & dataset
import seaborn as sns
df = sns.load_dataset('iris')

# use the function scatterplot() to make a scatterplot
sns.scatterplot(x=df["sepal_length"], y=df["sepal_width"])

#We can see correlation in the scatterplot because we can see that there is a positive correlation
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# Now, let's add some more parameters to make this visualization more robust.

# %%
## Uncomment the line below to see the scatterplot with the hue parameter.
#sns.scatterplot(x=df["sepal_length"], y=df["sepal_width"], data=df, hue="species")

## Uncomment the line below to see the scatterplot with the hue and style parameter.
sns.scatterplot(x=df["sepal_length"], y=df["sepal_width"], data=df, hue="species", style="species") # style of data pts
plt.title('Scatter Plot By Species')
# Out:
# Text(0.5, 1.0, 'Scatter Plot By Species')

# %% [markdown]
# #### __Class Discussion:__
#
# Take a second and read through the documentation on scatterplots.
#
# __Q:__ Did you learn anything new that you can do with scatterplots from the documentation you just read or from the outputs we produced above?
#
# __________________________________________________________________________________________________
#
# Now, return to the [data-to-viz](https://www.data-to-viz.com/) website.
# * Click __Chart Types__ from the menu bar.
#
# __Group A:__
# * In the row of GRAY icons, click on 5th icon. This is a connected scatterplot.
# * Take a moment and read about __Connected Scatter plots__.
#
# __Group B:__
# * In the row of GRAY icons, click on 6th icon. This is a 2D density plot.
# * Take a moment and read about __Contour Plots__ and the __.kdeplot()__ function of the seaborn library.

# %%
# Group A: Create a Connected Scatterplot

sns.lineplot(x=df["sepal_length"], y=df["sepal_width"], data=df, hue=df["species"], marker='o')
plt.title('Simple Connected Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Simple Connected Scatter Plot')

# %%
# Group B: Create a Contour Plot

sns.set_style("white")
sns.kdeplot(x=df.sepal_width, y=df.sepal_length, cmap="Reds", fill=True)
plt.show()
#the reder version

# %%
# You can also create a heatmap using the .histplot() function with the x and y parameters.

plt.figure(figsize=(8, 6))
sns.histplot(df, x="sepal_length", y="sepal_width", bins=20, cbar=True, cmap="YlGnBu")

plt.title("Heatmap: Sepal Length vs. Sepal Width Density")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.show()
#this is showing us

# %% [markdown]
# __What this Visualization Tells You:__
#
# * __The "Core" Cluster:__ There is a high-density area where sepal width is around 3.0 cm and sepal length is between 5.5 and 6.5 cm. This is the most "average" iris flower.
#
# * __The Setosa Outlier:__ You may see a smaller, isolated "hot spot" with very high sepal widths (3.5cm+) and very short sepal lengths (<5.0cm). This represents the Iris Setosa species, which is physically distinct from the others.
#
# * __Correlation Shape:__ If the "heat" forms a diagonal line, it suggests a strong correlation. For sepal length vs. width, the heat is often more of a blob, reflecting the weak correlation between these two specific features.

# %% [markdown]
# #### __Class Discussion:__
#
# __Q:__ What did you observe from your groups' visualization (connected scatter plot or counter plot)?
#
# __Q:__ Compare all three visualizations. What are the benefits and drawbacks of of using each of these visualizations?
#
# __________________________________________________________________________________________________

# %% [markdown]
# ### __Answer to Question 2:__
# A comparison of sepal length and sepal width across the three Iris species reveals some correlation for the setosa species. However, this correlation is not as strong for the other two species.
# __________________________________________________________________________________________________

# %% [markdown]
# # Section 3: Ranking
#
# ### __Question 3:__ How does the pedal length for the species setosa rank against the other species in the Iris dataset?
#
# Again, let's first make sure we understand the question being asked.
#
# __________________________________________________________________________________________________
#
# * __Rank__ in data visualization refers to the ordering of data points from usually greatest to least in frequency.
# * __Petal Length:__ The length of the inner colored petals.
#
# Let's begin to answer this question by you taking a moment to review the visualization options available under RANKING on the [data-to-viz](https://www.data-to-viz.com/) website.

# %%
# Create a bar chart using the .bar() function

# Define the parameters
height = df['petal_length']
bars = df['species']
color = ['lightblue', 'blue', 'purple']

# Create bars
plt.bar(df['species'], df['petal_length'], color=color)
#there are colors on top of colors
# Out:
# <BarContainer object of 150 artists>

# %% [markdown]
# #### __Class Discussion:__
#
# __Q:__ Why does the bar plot show all three colors across all three species?
#
# __Q:__ Do you find this aspect of the bar plot intuitive?
#
# __Q:__ Does this aspect bring clarity or confusion to the viewer?

# %%
# Create a Lollipop Plot

x = df['petal_length']
values = df['species']

# stem function
plt.stem(x, values)
plt.show()

# %% [markdown]
# __Polar Bar Chart__
#
# The Anatomy of the Plot:
#
# * The Circular Axis (Angles): The 360 degrees of the circle are divided into three equal segments, one for each species: Setosa, Versicolor, and Virginica.
#
# * The Radial Axis (Distance from Center): The "height" of each bar is measured by its distance from the center point of the circle. A longer bar indicates a higher mean value.
#
# The Bars:
# - Length: Represents the specific value of the mean petal length (in cm).
#
# - Width: The angular width is set to be quite wide to fill the circular space for better visual balance.

# %%
# Create a Polar Bar Chart

# Load dataset and calculate means
df_mean = df.groupby("species")["petal_length"].mean()

# Set up the polar coordinates
labels = df_mean.index
values = df_mean.values
num_vars = len(labels)

# Compute angles for each bar
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
# "Close" the circle by appending the first value to the end
values = np.concatenate((values, [values[0]]))
angles += angles[:1]

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

# Draw the bars
ax.bar(angles[:-1], df_mean.values, color=['#440154', '#21918c', '#fde725'], alpha=0.7, width=1.5)

# Fix labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
ax.set_title("Mean Petal Length by Species", va='bottom')

plt.show()

# %% [markdown]
# __Understanding the Results:__
#
# * __Setosa (Shortest Bar):__ The bar is very close to the center. This reflects that Setosa has the smallest average petal length (typically around 1.46cm).
# * __Versicolor (Medium Bar):__ The bar extends significantly further than Setosa, showing an average length of roughly 4.26cm.
# * __Virginica (Longest Bar):__ This bar reaches the furthest toward the outer edge of the circle, representing the largest average petal length of roughly 5.55cm.

# %% [markdown]
# #### __Question 3:__ How does the pedal length for the species setosa rank against the other species in the Iris dataset?
#
# __Answer to Question 3:__
# The pedal length of the setosa species is significantly shorter than that of the versicolor and virginica species.

# %% [markdown]
# # Section 4: Part of a Whole

# %%
# FIRST - pip install plotly

import plotly.express as px
# Load the iris dataset
df = px.data.iris()

# Create a treemap sized by petal_width
# 'path' creates the hierarchy: Species -> Individual Sample ID
fig = px.treemap(df, 
                 path=['species'], 
                 values='petal_width',
                 color='species',
                 title="Iris Treemap: Rectangle Size by Petal Width")

fig.show()

# %% [markdown]
# #### __What this Treemap Shows:__
#
# * __Hierarchy:__ The largest rectangles represent the three species (Setosa, Versicolor, Virginica).
#
# * __Size (Area):__ The size of each species block reflects the sum of the value you chose (e.g., petal length). Since * * Virginica has the longest petals, its section will be the largest.
#
# * __Individual Samples:__ Inside each species block, you can see smaller rectangles representing individual flower samples.
#
# ________________________________________________________________________________________________

# %% [markdown]
# A __Sunburst chart__ is essentially a radial treemap (or pie chart). It uses concentric circles to show hierarchy, with the inner circle representing the root and outer rings showing further detail.
#
# In the Iris dataset, a Sunburst chart is often used to visualize the hierarchy of Species → Individual Samples, with the size of each segment determined by a feature like petal width.

# %%
# Create the Sunburst chart
fig = px.sunburst(df, 
                  path=['species'], 
                  values='petal_width',
                  color='species',
                  title="Iris Sunburst: Sized by Petal Width")

fig.show()

# %% [markdown]
# #### How to Read This Chart
# * The Center (Inner Ring): Represents the three Iris species (Setosa, Versicolor, Virginica).
#
# * The Outer Ring: Shows individual flower samples within those species.
#
# * Segment Size: The "arc" or angle of each segment is proportional to its petal width. You will see the Virginica section occupies the largest portion of the circle because it has the widest petals.

# %% [markdown]
# ##### Referring to the creation of  venn diagram below
#
# This approach calculates the range (min to max) of petal widths for each species and creates a Venn diagram showing how many flowers from each species fall into shared measurement "bins."

# %%
# FIRST - pip install matplotlib-venn

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# Load the dataset
iris = sns.load_dataset('iris')

# Define sets based on Petal Width thresholds or specific values
# Example: Let's see which species share common petal width values
setosa_widths = set(iris[iris['species'] == 'setosa']['petal_width'])
versicolor_widths = set(iris[iris['species'] == 'versicolor']['petal_width'])
virginica_widths = set(iris[iris['species'] == 'virginica']['petal_width'])

# Create the Venn Diagram
plt.figure(figsize=(8, 8))
venn3([setosa_widths, versicolor_widths, virginica_widths], 
      set_labels=('Setosa', 'Versicolor', 'Virginica'),
      set_colors=('skyblue', 'lightgreen', 'salmon'), 
      alpha=0.7)

plt.title("Overlap of Unique Petal Width Values (cm) by Species")
plt.show()

# %% [markdown]
# #### Explanation:
#
# * The Circles: Each circle represents a species and contains all the unique measurement values for petal width found in that group.
#
# * Setosa (Isolated): You will notice the Setosa circle has zero overlap with the other two. This is because Setosa petal widths are very small (0.1–0.6 cm) and don't match the larger measurements of the other species.
#
# * Versicolor vs. Virginica (Overlap): These two circles will typically overlap. This tells you there are specific petal widths (e.g., 1.4 cm or 1.8 cm) that appear in both species, making that specific measurement a "shared" characteristic.

# %%
#FIRST - pip install pywaffle


import matplotlib.pyplot as plt
from pywaffle import Waffle
import seaborn as sns

# Load dataset
iris = sns.load_dataset("iris")

# Count occurrences of each species
data = iris['species'].value_counts().to_dict()

# Create the Waffle Chart
fig = plt.figure(
    FigureClass=Waffle,
    rows=10, 
    values=data, 
    colors=["#440154", "#21918c", "#fde725"],
    title={'label': 'Species Distribution in Iris Dataset', 'loc': 'left'},
    labels=[f"{k} ({v})" for k, v in data.items()],
    legend={'loc': 'lower left', 'bbox_to_anchor': (0, -0.2), 'ncol': 3, 'frameon': False}
)

plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# This script calculates the count of each species and displays them as a 10 x 15 grid, where each icon represents one flower.
#
# Since the Iris dataset contains 50 samples for each of the three species, a waffle chart is an excellent way to visualize this perfectly even distribution.
